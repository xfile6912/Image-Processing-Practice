# %%
import numpy as np
import os
import cv2
from imageio import imread
import matplotlib.pyplot as plt
# %matplotlib inline
print("PACKAGE LOADED")
# Out:
# PACKAGE LOADED

# %%
cwd=os.getcwd()
print("Current folder is %s" %(cwd))
# Out:
# Current folder is /Users/baeseonghyun/Image-Processing-Practice/basic_image_handling

# %%
def print_typeshape(img):
    print("Type is %s" %(type(img)))
    print("Shape is %s" % (img.shape, ))

# %%
cat = cv2.cvtColor(cv2.imread("./../img/cat.jpg"), cv2.COLOR_BGR2RGB);
print_typeshape(cat)
plt.figure(0)
plt.imshow(cat)
plt.title("CAT")
plt.draw()
# Out:
# Type is <class 'numpy.ndarray'>
# Shape is (1280, 1920, 3)

# %%
cat2=np.array(cat).astype(float)
print_typeshape(cat2)
plt.figure(0)
plt.imshow(cat2/255)
plt.title("Original Image with imread.astype(float)/255")
plt.draw()
# Out:
# Type is <class 'numpy.ndarray'>
# Shape is (1280, 1920, 3)

# %%
catsmall = cv2.resize(cat, dsize=(100, 100), interpolation=cv2.INTER_CUBIC)
print_typeshape(catsmall);

plt.figure(1)
plt.imshow(catsmall)
plt.title("resized image")
plt.draw()
# Out:
# Type is <class 'numpy.ndarray'>
# Shape is (100, 100, 3)

# %%
def rgb2gray(rgb):
    if len(rgb.shape) == 3:
        return np.dot(rgb[...,:3], [.299, 0.587, 0.114])
    else:
        print("Current Image if Gray!")
        return rgb

# %%
catsmallgray = rgb2gray(catsmall)
print_typeshape(catsmallgray)

plt.imshow(catsmallgray, cmap=plt.get_cmap("gray"))
plt.title("[imshow] Gray Image")
plt.draw()
# Out:
# Type is <class 'numpy.ndarray'>
# Shape is (100, 100)

# %%
catrowvec=np.reshape(catsmallgray, (1, -1))
print("size of catrowvec is %s" , catrowvec.shape);
print("type of catrowvec is %s", type(catrowvec));
# Out:
# size of catrowvec is %s (1, 10000)
# type of catrowvec is %s <class 'numpy.ndarray'>
